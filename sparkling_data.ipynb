# %%
#Import modules
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Read the csv file downloaded from https://wineinstitute.org/our-industry/statistics/us-sparkling-wine-champagne-shipments/

sparkling_data = pd.read_csv('sparkling_wine_data.csv')
sparkling_data
# Out:
#     Year California Winery Sparkling Other States Sparkling  \
# 0   2022                      11,567                  1,397
# 1   2021                      12,117                  1,408
# 2   2020                      10,415                  1,299
# 3   2019                      10,851                  1,143
# 4   2018                      10,914                    618
# 5   2017                      10,926                    331
# 6   2016                      10,651                    386
# 7   2015                       9,362                  1,043
# 8   2014                       8,434                  1,350
# 9   2013                       8,317                  1,133
# 10  2012                       8,259                  1,131
# 11  2011                       8,311                    950
# 12  2010                       7,875                  1,136
# 13  2009                       7,378                  1,238
# 14  2008                       6,581                  1,609
# ...

# %%
sparkling_data.set_index(['Year'])
# Out:
#      California Winery Sparkling Other States Sparkling Total U.S. Sparkling  \
# Year
# 2022                      11,567                  1,397               12,964
# 2021                      12,117                  1,408               13.525
# 2020                      10,415                  1,299               11,714
# 2019                      10,851                  1,143               11,994
# 2018                      10,914                    618               11,532
# 2017                      10,926                    331               11,257
# 2016                      10,651                    386               11,037
# 2015                       9,362                  1,043               10,405
# 2014                       8,434                  1,350                9,784
# 2013                       8,317                  1,133                9,450
# 2012                       8,259                  1,131                9,389
# ...

# %%
# Clean the "California Winery Sparkling" column
sparkling_data.dtypes
# Out:
# Year                            int64
# California Winery Sparkling     int64
# Other States Sparkling         object
# Total U.S. Sparkling           object
# Foreign Sparkling              object
# Total Sparkling                object
# dtype: object

# %%
plt.figure(figsize=(10, 6))
plt.plot(sparkling_data['Year'], sparkling_data['California Winery Sparkling'], marker='o', linestyle='-', color='b')
plt.title('California Winery Sparkling Production Over the Years')
plt.xlabel('Year')
plt.ylabel('California Winery Sparkling')
plt.grid(True)
plt.show()
